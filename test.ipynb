# %%
import requests
import datetime  
import json
import random
import hmac
from hashlib import sha1
import base64
import time

from flask import Flask, request, abort

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage,
)
import configparser as ConfigParser

ini_data=ConfigParser.ConfigParser()
ini_data.read('key.ini')

#line資訊
line_bot_api = LineBotApi(ini_data.get('line_bot','key'))
handler = WebhookHandler(ini_data.get('line_bot','secret'))
#line資訊

#MOTC資訊
APPID = ini_data.get('MOTC','key')
APPKey = ini_data.get('MOTC','secret')
#MOTC資訊

# %%
loc='%s,%s'%(24.144267,120.732028)
res=requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword=景點&location=%s&radius=500&key=AIzaSyD9ojwRyJKMDqorLnjpoaRT7s94S2EAkVA&language=zh-TW'%loc)
sent_data=json.loads(res.text)

for item in sent_data['results']:
    print('https://www.google.com.tw/maps/search/%s'%item['name'])
# Out:
# https://www.google.com.tw/maps/search/坪林森林公園

# %%
# Out:
# 坪林森林公園

# %%
#時間轉sec
def get_sec(time_str):
    h, m, s = time_str.split(':')
    try:
        sent=int(h) * 60 + int(m) 
    except ValueError as e1:
        sent=time_str
    return sent

#製作驗證簽名
def head(APPID,APPKey):
    X_Date=datetime.datetime.now(datetime.timezone.utc).strftime("%a, "+"%d %b "+"%Y %H:%M:%S"+" GMT")
    print(X_Date)

    sent_APPKey = str.encode(APPKey)
    sent_time = str.encode("x-date: "+X_Date)
    hmac_ans = hmac.new(sent_APPKey,sent_time ,sha1)
    hmac_ans=base64.b64encode(hmac_ans.digest())
    hmac_ans=str(hmac_ans)[2:len(str(hmac_ans))-1]
    print(hmac_ans)

    Authorization='hmac username="'+APPID+'", algorithm="hmac-sha1", headers="x-date", signature="'+hmac_ans+'"'

    headers={ 'Authorization': Authorization, 'X-Date':X_Date}
    return headers
########################

bus_id=input('車牌號碼：')
print(bus_id)

headers=head(APPID,APPKey)

res=requests.get('http://ptx.transportdata.tw/MOTC/v2/Bus/EstimatedTimeOfArrival/City/Taichung/'+bus_id+'?$format=JSON',headers=headers)
json_data=json.loads(res.text)
#print(res)

sent_dict1=[]
sent_dict2=[]
sent_ans1=''
sent_ans2=''
format = '%Y-%m-%dT%H:%M:%S+08:00'
localtime=time.strftime("%Y-%m-%dT%H:%M:%S+08:00", time.localtime())
# Out:
# 車牌號碼：30
# 30
# Wed, 27 Jun 2018 04:28:39 GMT
# ZewHp2P9W8BZOJDlBGfTNKgiEUY=
# <Response [200]>

# %%
res_pos=requests.get('http://ptx.transportdata.tw/MOTC/v2/Bus/RealTimeByFrequency/City/Taichung/'+bus_id+'?$format=JSON',headers=headers)
json_data_pos=json.loads(res_pos.text)

posLat=json_data_pos[int(len(json_data_pos)/2)]['BusPosition']['PositionLat']#取中間一點的點會比較好 但實際號碼是亂碼 其實沒差
posLon=json_data_pos[int(len(json_data_pos)/2)]['BusPosition']['PositionLon']#取中間一點的點會比較好 但實際號碼是亂碼 其實沒差

# %%
for item in json_data:
    if item['Direction']==0 and str(item['RouteID'])==bus_id:
        try:
            #NextBusTime=datetime.datetime.strptime(item['NextBusTime'], format)-datetime.datetime.strptime(localtime, format)
            #NextBusTime=str(NextBusTime)

            if item['EstimateTime']>=0:
                EstimateTime=item['EstimateTime']/60
            elif item['EstimateTime']==-3:
                EstimateTime='離駛'
            else:
                EstimateTime='未發'
            sent_dict1+=[{'sent_name1':item['StopName']['Zh_tw'],'sent_id1':item['StopSequence'],'sent_time1':EstimateTime}]
        except KeyError as e1:
            sent_dict1+=[{'sent_name1':item['StopName']['Zh_tw'],'sent_id1':item['StopSequence'],'sent_time1':'尚未發車'}]
    if item['Direction']==1 and str(item['RouteID'])==bus_id:
        try:
            #NextBusTime=datetime.datetime.strptime(item['NextBusTime'], format)-datetime.datetime.strptime(localtime, format)
            #NextBusTime=str(NextBusTime)
            if item['EstimateTime']>=0:
                EstimateTime=item['EstimateTime']/60
            elif item['EstimateTime']==-3:
                EstimateTime='離駛'
            else:
                EstimateTime='未發'
            sent_dict2+=[{'sent_name2':item['StopName']['Zh_tw'],'sent_id2':item['StopSequence'],'sent_time2':EstimateTime}]
        except KeyError as e1:
            sent_dict2+=[{'sent_name2':item['StopName']['Zh_tw'],'sent_id2':item['StopSequence'],'sent_time2':'尚未發車'}]

sent_dict1.sort(key=lambda d:d['sent_id1']) 
sent_dict2.sort(key=lambda d:d['sent_id2'])  

for item in sent_dict1:
    sent_ans1+=str(item['sent_id1'])+'.'+item['sent_name1']+' '+str(item['sent_time1'])+'\n'
for item in sent_dict2:
    sent_ans2+=str(item['sent_id2'])+'.'+item['sent_name2']+' '+str(item['sent_time2'])+'\n'

# %%
line_bot_api.reply_message(
    event.reply_token,[TextSendMessage(text='路線1：\n'+sent_ans1),TextSendMessage(text='路線2：\n'+sent_ans2)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-260677c29db8> in <module>()
#       1 line_bot_api.reply_message(
# ----> 2     event.reply_token,[TextSendMessage(text='路線1：\n'+sent_ans1),TextSendMessage(text='路線2：\n'+sent_ans2)])
#
# NameError: name 'event' is not defined

# %%
print(sent_ans1)
# Out:
# 1.仁友停車場 尚未發車
# 2.復興電台 尚未發車
# 3.嶺東科大第二校區(中台路) 尚未發車
# 4.東光公司 尚未發車
# 5.嶺東三站 尚未發車
# 6.干城六村 尚未發車
# 7.嶺東科技大學(嶺東路) 尚未發車
# 8.嶺東高中 尚未發車
# 9.春社里(永春南路) 尚未發車
# 10.劉厝里 尚未發車
# 11.下新生里 尚未發車
# 12.永定里二站(永春東路) 尚未發車
# 13.永定里(永春東路) 尚未發車
# 14.永春東黎明路口 尚未發車
# 15.萬和國中 尚未發車
# 16.第四分局 尚未發車
# 17.文心南南屯路口 尚未發車
# 18.南屯文心路口 尚未發車
# 19.田心仔(清真寺) 尚未發車
# 20.下田心仔 尚未發車
# 21.土庫 尚未發車
# 22.崇倫國中(南屯路) 0.0
# 23.靜和醫院 1.0
# 24.南屯美村路口 1.0
# 25.永安市場 3.0
# 26.五權樂群街口 3.0
# 27.五權柳川西路口 4.0
# 28.五權公館路口 4.0
# 29.五權五廊街口 5.0
# 30.大墩文化中心(五權路) 6.0
# 31.五權自立街口 8.0
# 32.五權民生路口 9.0
# 33.臺中教育大學 10.0
# 34.民權中華路口 11.0
# 35.臺中醫院 12.0
# 36.臺中州廳 14.0
# 37.合作金庫 15.0
# 38.彰化銀行(自由路) 15.0
# 39.星動銀河旅站 16.0
# 40.干城站 19.0

# %%
def gaga_say(select):
    rad=random.randint(0,2)
    word1=['是香香空氣呱!','出去玩嘎~','是藍天 是藍天~']
    word2=['有點臭臭嘎...','想出去但臭臭..','天空陰陰呱..']
    word3=['完全不敢出去了呱呱..!','口罩快給我呱!','這個雲好恐怖嘎!']
    if select==1:
        return word1[rad]
    elif select==2:
        return word2[rad]
    elif select==3:
        return word3[rad]

# %%
def Dust2_5_is_what():
    json_data_AQI=''
    res_AQI=requests.get('https://airmap.g0v.asper.tw/json/airmap.json')
    json_data_AQI=json.loads(res_AQI.text)
    scale=3#pm2.5倍率
    dust_data=[]
    map_ori_list=[]
    map_ori=''
    map_des=''
    get_map=[]

    for item in json_data_AQI:
        if item['Geometry']!=None:
            if item['Geometry']['COUNTYNAME']=='臺中市':
                Dust2_5=int(item['Data']['Dust2_5'])*scale
                dust_data+=[{'經緯':'%s,%s'%(str(item['LatLng']['lat']),str(item['LatLng']['lng'])),'位置':item['Geometry']['TOWNNAME'],'pm2.5':Dust2_5}]
    #print(dust_data)偵錯

    for item in dust_data:
        map_ori_list+=[item['位置']]
    map_ori_list=list(set(map_ori_list))
    for item in dust_data:
        for item2 in map_ori_list:
            if item['位置']==item2:
                map_ori+=item['經緯']+'|'
            break

    map_ori=map_ori[0:len(map_ori)-1]
    map_des='%s,%s'%(posLat,posLon)
    map_url='https://maps.googleapis.com/maps/api/distancematrix/json?origins=%s&destinations=%s&mode=driving&language=zh-TW&key=AIzaSyD9ojwRyJKMDqorLnjpoaRT7s94S2EAkVA'%(map_ori,map_des)
    print(map_url)
    res_map=requests.get(map_url)
    json_data_map=json.loads(res_map.text)

    for item in json_data_map['rows']:
        try:
            get_map+=[item['elements'][0]['distance']['value']]
        except KeyError as e3:
            get_map+=[9999999]
    get_map.index(min(get_map))

    for item in dust_data:
        if item['位置']==map_ori_list[get_map.index(min(get_map))]:
            Dust2_5=item['pm2.5']
            #print(map_ori_list[get_map.index(min(get_map))])偵錯
            #print(Dust2_5)偵錯
            break#一抓到位置相同即跳出迴圈

    if Dust2_5>100:
        ret=gaga_say(3)
    elif Dust2_5>50:
        ret=gaga_say(2)
    else:
        ret=gaga_say(1)

    return ret

# %%
json_data_AQI[0]['LatLng']
# Out:
# {'lat': 23.97008, 'lng': 120.56077}

# %%
json_data_AQI
# Out:
# [{'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:19Z',
#    'Dust2_5': 21,
#    'Humidity': 71,
#    'Temperature': 31},
#   'Geometry': {'COUNTYCODE': '10007',
#    'COUNTYID': 'N',
#    'COUNTYNAME': '彰化縣',
#    'TOWNCODE': '10007100',
#    'TOWNENG': 'Yuanlin City',
#    'TOWNID': 'N05',
#    'TOWNNAME': '員林市'},
#   'LatLng': {'lat': 23.97008, 'lng': 120.56077},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': '0928958262',
#   'uniqueKey': '0928958262'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:01:32Z',
#    'Dust2_5': 0,
#    'Humidity': 0,
#    'Temperature': 0},
#   'Geometry': None,
#   'LatLng': {'lat': 25.1933, 'lng': 121.787},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': '9E65F90C12E0',
#   'uniqueKey': '9E65F90C12E0'},
#  {'Analysis': {'ranking': 1, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:08Z',
#    'Dust2_5': 47,
#    'Humidity': 88,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '10009',
#    'COUNTYID': 'P',
#    'COUNTYNAME': '雲林縣',
#    'TOWNCODE': '10009010',
#    'TOWNENG': 'Douliu City',
#    'TOWNID': 'P01',
#    'TOWNNAME': '斗六市'},
#   'LatLng': {'lat': 23.71678, 'lng': 120.54518},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE3895C2D4',
#   'uniqueKey': 'FT_LIVE3895C2D4'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:11Z',
#    'Dust2_5': 4,
#    'Humidity': 49,
#    'Temperature': 27},
#   'Geometry': None,
#   'LatLng': {'lat': 20.51861, 'lng': 119.94172},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE4C870000',
#   'uniqueKey': 'FT_LIVE4C870000'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:48Z',
#    'Dust2_5': 29,
#    'Humidity': 53,
#    'Temperature': 33},
#   'Geometry': None,
#   'LatLng': {'lat': 23, 'lng': 120},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE4C870122',
#   'uniqueKey': 'FT_LIVE4C870122'},
#  {'Analysis': {'ranking': 1, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:24Z',
#    'Dust2_5': 11,
#    'Humidity': 80,
#    'Temperature': 15},
#   'Geometry': None,
#   'LatLng': {'lat': 37.8714, 'lng': -122.2599},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8C3C2467_G5',
#   'uniqueKey': 'FT_LIVE8C3C2467_G5'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:43Z',
#    'Dust2_5': 6,
#    'Humidity': 80,
#    'Temperature': 15},
#   'Geometry': None,
#   'LatLng': {'lat': 37.8714, 'lng': -122.2589},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8C3C2467_G7',
#   'uniqueKey': 'FT_LIVE8C3C2467_G7'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:42Z',
#    'Dust2_5': 5,
#    'Humidity': 78,
#    'Temperature': 30},
#   'Geometry': {'COUNTYCODE': '10013',
#    'COUNTYID': 'T',
#    'COUNTYNAME': '屏東縣',
#    'TOWNCODE': '10013030',
#    'TOWNENG': 'Donggang Township',
#    'TOWNID': 'T03',
#    'TOWNNAME': '東港鎮'},
#   'LatLng': {'lat': 22.47822, 'lng': 120.48735},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8C3C2757',
#   'uniqueKey': 'FT_LIVE8C3C2757'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:31Z',
#    'Dust2_5': 36,
#    'Humidity': 53,
#    'Temperature': 35},
#   'Geometry': {'COUNTYCODE': '10010',
#    'COUNTYID': 'Q',
#    'COUNTYNAME': '嘉義縣',
#    'TOWNCODE': '10010150',
#    'TOWNENG': 'Meishan Township',
#    'TOWNID': 'Q16',
#    'TOWNNAME': '梅山鄉'},
#   'LatLng': {'lat': 23.58162, 'lng': 120.55973},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7A85C',
#   'uniqueKey': 'FT_LIVE8CE7A85C'},
#  {'Analysis': {'ranking': 3,
#    'status': 'longterm-pollution|malfunction|shortterm-pollution'},
#   'Data': {'Create_at': '2018-06-27T04:05:09Z',
#    'Dust2_5': 41,
#    'Humidity': 78,
#    'Temperature': 34},
#   'Geometry': {'COUNTYCODE': '10013',
#    'COUNTYID': 'T',
#    'COUNTYNAME': '屏東縣',
#    'TOWNCODE': '10013030',
#    'TOWNENG': 'Donggang Township',
#    'TOWNID': 'T03',
#    'TOWNNAME': '東港鎮'},
#   'LatLng': {'lat': 22.47731, 'lng': 120.48744},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7A861',
#   'uniqueKey': 'FT_LIVE8CE7A861'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:20Z',
#    'Dust2_5': 24,
#    'Humidity': 59,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000030',
#    'TOWNENG': 'Zuoying District',
#    'TOWNID': 'E03',
#    'TOWNNAME': '左營區'},
#   'LatLng': {'lat': 22.666150000000002, 'lng': 120.31498},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7A866',
#   'uniqueKey': 'FT_LIVE8CE7A866'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:57Z',
#    'Dust2_5': 7,
#    'Humidity': 60,
#    'Temperature': 34},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000120',
#    'TOWNENG': 'Fengshan District',
#    'TOWNID': 'E12',
#    'TOWNNAME': '鳳山區'},
#   'LatLng': {'lat': 22.60558, 'lng': 120.32682},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7A87E',
#   'uniqueKey': 'FT_LIVE8CE7A87E'},
#  {'Analysis': {'ranking': 4, 'status': 'longterm-pollution|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:36Z',
#    'Dust2_5': 18,
#    'Humidity': 48,
#    'Temperature': 29},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000100',
#    'TOWNENG': 'Neihu District',
#    'TOWNID': 'A14',
#    'TOWNNAME': '內湖區'},
#   'LatLng': {'lat': 25.07711, 'lng': 121.57902},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7AA00',
#   'uniqueKey': 'FT_LIVE8CE7AA00'},
#  {'Analysis': {'ranking': 2, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:04Z',
#    'Dust2_5': 7,
#    'Humidity': 77,
#    'Temperature': 15},
#   'Geometry': None,
#   'LatLng': {'lat': 37.8724, 'lng': -122.2599},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7AA11_G3',
#   'uniqueKey': 'FT_LIVE8CE7AA11_G3'},
#  {'Analysis': {'ranking': 2, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:00Z',
#    'Dust2_5': 5,
#    'Humidity': 77,
#    'Temperature': 15},
#   'Geometry': None,
#   'LatLng': {'lat': 37.8724, 'lng': -122.2589},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7AA11_GA',
#   'uniqueKey': 'FT_LIVE8CE7AA11_GA'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:12Z',
#    'Dust2_5': 9,
#    'Humidity': 47,
#    'Temperature': 27},
#   'Geometry': None,
#   'LatLng': {'lat': 20.51861, 'lng': 119.94172},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVE8CE7AB21',
#   'uniqueKey': 'FT_LIVE8CE7AB21'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:02Z',
#    'Dust2_5': 22,
#    'Humidity': 62,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '10008',
#    'COUNTYID': 'M',
#    'COUNTYNAME': '南投縣',
#    'TOWNCODE': '10008030',
#    'TOWNENG': 'Caotun Township',
#    'TOWNID': 'M03',
#    'TOWNNAME': '草屯鎮'},
#   'LatLng': {'lat': 23.97571, 'lng': 120.70494},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVEDDDD482E',
#   'uniqueKey': 'FT_LIVEDDDD482E'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:26Z',
#    'Dust2_5': 8,
#    'Humidity': 47,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000090',
#    'TOWNENG': 'Nangang District',
#    'TOWNID': 'A13',
#    'TOWNNAME': '南港區'},
#   'LatLng': {'lat': 25.03959, 'lng': 121.29158},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT_LIVEEE155FF7',
#   'uniqueKey': 'FT_LIVEEE155FF7'},
#  {'Analysis': {'ranking': 1, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:03Z',
#    'Dust2_5': 24,
#    'Humidity': 0,
#    'Temperature': 0},
#   'Geometry': {'COUNTYCODE': '10020',
#    'COUNTYID': 'I',
#    'COUNTYNAME': '嘉義市',
#    'TOWNCODE': '10020010',
#    'TOWNENG': 'E. District',
#    'TOWNID': 'I01',
#    'TOWNNAME': '東區'},
#   'LatLng': {'lat': 23.47938, 'lng': 120.44917},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT1_116',
#   'uniqueKey': 'FT1_116'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:40Z',
#    'Dust2_5': 9,
#    'Humidity': 53.7,
#    'Temperature': 36},
#   'Geometry': {'COUNTYCODE': '10007',
#    'COUNTYID': 'N',
#    'COUNTYNAME': '彰化縣',
#    'TOWNCODE': '10007010',
#    'TOWNENG': 'Zhanghua City',
#    'TOWNID': 'N01',
#    'TOWNNAME': '彰化市'},
#   'LatLng': {'lat': 24.08996, 'lng': 120.5441},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT1_censer',
#   'uniqueKey': 'FT1_censer'},
#  {'Analysis': {'ranking': 5, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:19Z',
#    'Dust2_5': 35,
#    'Humidity': 62.69,
#    'Temperature': 30.74},
#   'Geometry': {'COUNTYCODE': '10009',
#    'COUNTYID': 'P',
#    'COUNTYNAME': '雲林縣',
#    'TOWNCODE': '10009020',
#    'TOWNENG': 'Dounan Township',
#    'TOWNID': 'P02',
#    'TOWNNAME': '斗南鎮'},
#   'LatLng': {'lat': 23.66758, 'lng': 120.47541},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT1_Dounan_Indoor',
#   'uniqueKey': 'FT1_Dounan_Indoor'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:43Z',
#    'Dust2_5': 27,
#    'Humidity': 74.62,
#    'Temperature': 32.67},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000090',
#    'TOWNENG': 'Liujia District',
#    'TOWNID': 'D17',
#    'TOWNNAME': '六甲區'},
#   'LatLng': {'lat': 23.24255, 'lng': 120.32438},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT1_KGTO',
#   'uniqueKey': 'FT1_KGTO'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:39Z',
#    'Dust2_5': 2,
#    'Humidity': 57.6,
#    'Temperature': 35.5},
#   'Geometry': {'COUNTYCODE': '10004',
#    'COUNTYID': 'J',
#    'COUNTYNAME': '新竹縣',
#    'TOWNCODE': '10004100',
#    'TOWNENG': 'Baoshan Township',
#    'TOWNID': 'J11',
#    'TOWNNAME': '寶山鄉'},
#   'LatLng': {'lat': 24.76548, 'lng': 120.99062},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT1_RTL8710_E3',
#   'uniqueKey': 'FT1_RTL8710_E3'},
#  {'Analysis': {'ranking': 0, 'status': 'longterm-pollution|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:07Z',
#    'Dust2_5': 30,
#    'Humidity': 54,
#    'Temperature': 32},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000010',
#    'TOWNENG': 'Songshan District',
#    'TOWNID': 'A01',
#    'TOWNNAME': '松山區'},
#   'LatLng': {'lat': 25.05026, 'lng': 121.57792},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_001_1',
#   'uniqueKey': 'FT3_001_1'},
#  {'Analysis': {'ranking': 3, 'status': 'longterm-pollution|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:05:06Z',
#    'Dust2_5': 15,
#    'Humidity': 49,
#    'Temperature': 30},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000020',
#    'TOWNENG': 'Xinyi District',
#    'TOWNID': 'A17',
#    'TOWNNAME': '信義區'},
#   'LatLng': {'lat': 25.04715, 'lng': 121.56989},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_009_1',
#   'uniqueKey': 'FT3_009_1'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:11Z',
#    'Dust2_5': 16,
#    'Humidity': 57,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000060',
#    'TOWNENG': 'Datong District',
#    'TOWNID': 'A09',
#    'TOWNNAME': '大同區'},
#   'LatLng': {'lat': 25.05413, 'lng': 121.51657},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_061_C',
#   'uniqueKey': 'FT3_061_C'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:04Z',
#    'Dust2_5': 24,
#    'Humidity': 58,
#    'Temperature': 34},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000060',
#    'TOWNENG': 'Datong District',
#    'TOWNID': 'A09',
#    'TOWNNAME': '大同區'},
#   'LatLng': {'lat': 25.0543, 'lng': 121.51772},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_061_E',
#   'uniqueKey': 'FT3_061_E'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:12Z',
#    'Dust2_5': 21,
#    'Humidity': 58,
#    'Temperature': 32},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000080',
#    'TOWNENG': 'Wenshan District',
#    'TOWNID': 'A11',
#    'TOWNNAME': '文山區'},
#   'LatLng': {'lat': 24.98994, 'lng': 121.57668},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_092_2',
#   'uniqueKey': 'FT3_092_2'},
#  {'Analysis': {'ranking': 2, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:07Z',
#    'Dust2_5': 8,
#    'Humidity': 60,
#    'Temperature': 32},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000120',
#    'TOWNENG': 'Beitou District',
#    'TOWNID': 'A16',
#    'TOWNNAME': '北投區'},
#   'LatLng': {'lat': 25.12624, 'lng': 121.46639},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_099_1',
#   'uniqueKey': 'FT3_099_1'},
#  {'Analysis': {'ranking': 0, 'status': 'longterm-pollution|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:05:03Z',
#    'Dust2_5': 32,
#    'Humidity': 54,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000100',
#    'TOWNENG': 'Neihu District',
#    'TOWNID': 'A14',
#    'TOWNNAME': '內湖區'},
#   'LatLng': {'lat': 25.06881, 'lng': 121.58868},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'FT3_141_2',
#   'uniqueKey': 'FT3_141_2'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:56Z',
#    'Dust2_5': 10,
#    'Humidity': 43.9,
#    'Temperature': 38.6},
#   'Geometry': {'COUNTYCODE': '10007',
#    'COUNTYID': 'N',
#    'COUNTYNAME': '彰化縣',
#    'TOWNCODE': '10007030',
#    'TOWNENG': 'Hemei Township',
#    'TOWNID': 'N03',
#    'TOWNNAME': '和美鎮'},
#   'LatLng': {'lat': 24.10827, 'lng': 120.53178},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'Hsu_001',
#   'uniqueKey': 'Hsu_001'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:04Z',
#    'Dust2_5': 14,
#    'Humidity': 0,
#    'Temperature': 0},
#   'Geometry': {'COUNTYCODE': '10007',
#    'COUNTYID': 'N',
#    'COUNTYNAME': '彰化縣',
#    'TOWNCODE': '10007080',
#    'TOWNENG': 'Huatan Township',
#    'TOWNID': 'N13',
#    'TOWNNAME': '花壇鄉'},
#   'LatLng': {'lat': 24.05069, 'lng': 120.5523},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'LASS-PI_025',
#   'uniqueKey': 'LASS-PI_025'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:10Z',
#    'Dust2_5': 15,
#    'Humidity': 99.9,
#    'Temperature': 28.5},
#   'Geometry': None,
#   'LatLng': {'lat': 14.63588, 'lng': 121.07757},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'LASS-SPS_025',
#   'uniqueKey': 'LASS-SPS_025'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:32Z',
#    'Dust2_5': 14,
#    'Humidity': 60.31,
#    'Temperature': 32.37},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000060',
#    'TOWNENG': 'Xitun District',
#    'TOWNID': 'B06',
#    'TOWNNAME': '西屯區'},
#   'LatLng': {'lat': 24.15561, 'lng': 120.63884},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'MYAIR_01',
#   'uniqueKey': 'MYAIR_01'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:16Z',
#    'Dust2_5': 0,
#    'Humidity': 75.6,
#    'Temperature': 100.7},
#   'Geometry': {'COUNTYCODE': '10008',
#    'COUNTYID': 'M',
#    'COUNTYNAME': '南投縣',
#    'TOWNCODE': '10008070',
#    'TOWNENG': 'Lugu Township',
#    'TOWNID': 'M07',
#    'TOWNNAME': '鹿谷鄉'},
#   'LatLng': {'lat': 23.70378, 'lng': 120.77557},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'NTUEF-NT-HEYPS',
#   'uniqueKey': 'NTUEF-NT-HEYPS'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:32Z',
#    'Dust2_5': 27,
#    'Humidity': 75.4,
#    'Temperature': 28.1},
#   'Geometry': {'COUNTYCODE': '10008',
#    'COUNTYID': 'M',
#    'COUNTYNAME': '南投縣',
#    'TOWNCODE': '10008070',
#    'TOWNENG': 'Lugu Township',
#    'TOWNID': 'M07',
#    'TOWNNAME': '鹿谷鄉'},
#   'LatLng': {'lat': 23.70406, 'lng': 120.77581},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'NTUEF-NT-NHPS',
#   'uniqueKey': 'NTUEF-NT-NHPS'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:17Z',
#    'Dust2_5': 30,
#    'Humidity': 66,
#    'Temperature': 33},
#   'Geometry': {'COUNTYCODE': '10008',
#    'COUNTYID': 'M',
#    'COUNTYNAME': '南投縣',
#    'TOWNCODE': '10008040',
#    'TOWNENG': 'Zhushan Township',
#    'TOWNID': 'M04',
#    'TOWNNAME': '竹山鎮'},
#   'LatLng': {'lat': 23.75635, 'lng': 120.67763},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'NTUEF-NY-YLPS',
#   'uniqueKey': 'NTUEF-NY-YLPS'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:59Z',
#    'Dust2_5': 12,
#    'Humidity': 62.7,
#    'Temperature': 26.8},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000350',
#    'TOWNENG': 'Annan District',
#    'TOWNID': 'D06',
#    'TOWNNAME': '安南區'},
#   'LatLng': {'lat': 23.05922, 'lng': 120.15508},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'UKN_001',
#   'uniqueKey': 'UKN_001'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:29Z',
#    'Dust2_5': 29,
#    'Humidity': 51.2,
#    'Temperature': 27.3},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000100',
#    'TOWNENG': 'Guantian District',
#    'TOWNID': 'D18',
#    'TOWNNAME': '官田區'},
#   'LatLng': {'lat': 23.16863, 'lng': 120.32975},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_1108426',
#   'uniqueKey': 'WF_1108426'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:22Z',
#    'Dust2_5': 16,
#    'Humidity': 66.9,
#    'Temperature': 30.2},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000040',
#    'TOWNENG': 'W. District',
#    'TOWNID': 'B04',
#    'TOWNNAME': '西區'},
#   'LatLng': {'lat': 24.14698, 'lng': 120.6632},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_1182189',
#   'uniqueKey': 'WF_1182189'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:12Z',
#    'Dust2_5': 28,
#    'Humidity': 72.6,
#    'Temperature': 32.9},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000140',
#    'TOWNENG': 'Daliao District',
#    'TOWNID': 'E14',
#    'TOWNNAME': '大寮區'},
#   'LatLng': {'lat': 22.6333, 'lng': 120.39641},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_12743501',
#   'uniqueKey': 'WF_12743501'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:06Z',
#    'Dust2_5': 13,
#    'Humidity': 76,
#    'Temperature': 34.4},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000060',
#    'TOWNENG': 'Xitun District',
#    'TOWNID': 'B06',
#    'TOWNNAME': '西屯區'},
#   'LatLng': {'lat': 24.15958, 'lng': 120.64959},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_1339188',
#   'uniqueKey': 'WF_1339188'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:02Z',
#    'Dust2_5': 0,
#    'Humidity': 75,
#    'Temperature': 31.9},
#   'Geometry': {'COUNTYCODE': '10009',
#    'COUNTYID': 'P',
#    'COUNTYNAME': '雲林縣',
#    'TOWNCODE': '10009030',
#    'TOWNENG': 'Huwei Township',
#    'TOWNID': 'P03',
#    'TOWNNAME': '虎尾鎮'},
#   'LatLng': {'lat': 23.74111, 'lng': 120.40173},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_1351549',
#   'uniqueKey': 'WF_1351549'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:36Z',
#    'Dust2_5': 16,
#    'Humidity': 71,
#    'Temperature': 34.7},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000230',
#    'TOWNENG': 'Wuri District',
#    'TOWNID': 'B23',
#    'TOWNNAME': '烏日區'},
#   'LatLng': {'lat': 24.10534, 'lng': 120.61096},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_1352505',
#   'uniqueKey': 'WF_1352505'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:34Z',
#    'Dust2_5': 11,
#    'Humidity': 50,
#    'Temperature': 33.3},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_1352643',
#   'uniqueKey': 'WF_1352643'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:03Z',
#    'Dust2_5': 28,
#    'Humidity': 54.5,
#    'Temperature': 34.2},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002030',
#    'TOWNENG': 'Suao Township',
#    'TOWNID': 'G09',
#    'TOWNNAME': '蘇澳鎮'},
#   'LatLng': {'lat': 24.64133, 'lng': 121.83259},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_14011622',
#   'uniqueKey': 'WF_14011622'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:23Z',
#    'Dust2_5': 16,
#    'Humidity': 0,
#    'Temperature': 0},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000180',
#    'TOWNENG': 'Daya District',
#    'TOWNID': 'B18',
#    'TOWNNAME': '大雅區'},
#   'LatLng': {'lat': 24.23815, 'lng': 120.63834},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_15601235',
#   'uniqueKey': 'WF_15601235'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:26Z',
#    'Dust2_5': 11,
#    'Humidity': 49,
#    'Temperature': 35.5},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_15635311',
#   'uniqueKey': 'WF_15635311'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:01Z',
#    'Dust2_5': 23,
#    'Humidity': 59.7,
#    'Temperature': 33.4},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000180',
#    'TOWNENG': 'Daya District',
#    'TOWNID': 'B18',
#    'TOWNNAME': '大雅區'},
#   'LatLng': {'lat': 24.22444, 'lng': 120.65007},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_15707714',
#   'uniqueKey': 'WF_15707714'},
#  {'Analysis': {'ranking': 0, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:25Z',
#    'Dust2_5': 14,
#    'Humidity': 65.9,
#    'Temperature': 29.4},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000160',
#    'TOWNENG': 'Taishan District',
#    'TOWNID': 'F06',
#    'TOWNNAME': '泰山區'},
#   'LatLng': {'lat': 25.05049, 'lng': 121.42831},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3942849',
#   'uniqueKey': 'WF_3942849'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:38Z',
#    'Dust2_5': 27,
#    'Humidity': 64,
#    'Temperature': 36},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000260',
#    'TOWNENG': 'Zuozhen District',
#    'TOWNID': 'D31',
#    'TOWNNAME': '左鎮區'},
#   'LatLng': {'lat': 23.05652, 'lng': 120.41057},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3968474',
#   'uniqueKey': 'WF_3968474'},
#  {'Analysis': {'ranking': 2, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:17Z',
#    'Dust2_5': 23,
#    'Humidity': 91.8,
#    'Temperature': 33.4},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000260',
#    'TOWNENG': 'Zuozhen District',
#    'TOWNID': 'D31',
#    'TOWNNAME': '左鎮區'},
#   'LatLng': {'lat': 23.05653, 'lng': 120.41056},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3968861',
#   'uniqueKey': 'WF_3968861'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:17Z',
#    'Dust2_5': 15,
#    'Humidity': 57.1,
#    'Temperature': 31.7},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3968873',
#   'uniqueKey': 'WF_3968873'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:09Z',
#    'Dust2_5': 9,
#    'Humidity': 68.9,
#    'Temperature': 28.7},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3969133',
#   'uniqueKey': 'WF_3969133'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:35Z',
#    'Dust2_5': 13,
#    'Humidity': 49.9,
#    'Temperature': 29},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3977129',
#   'uniqueKey': 'WF_3977129'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:34Z',
#    'Dust2_5': 5,
#    'Humidity': 47.8,
#    'Temperature': 24.6},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000060',
#    'TOWNENG': 'Xitun District',
#    'TOWNID': 'B06',
#    'TOWNNAME': '西屯區'},
#   'LatLng': {'lat': 24.18269, 'lng': 120.64681},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3977799',
#   'uniqueKey': 'WF_3977799'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:13Z',
#    'Dust2_5': 8,
#    'Humidity': 47.8,
#    'Temperature': 28.4},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3978155',
#   'uniqueKey': 'WF_3978155'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:29Z',
#    'Dust2_5': 16,
#    'Humidity': 44.9,
#    'Temperature': 37.5},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3978202',
#   'uniqueKey': 'WF_3978202'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:11Z',
#    'Dust2_5': 13,
#    'Humidity': 58.9,
#    'Temperature': 32.4},
#   'Geometry': None,
#   'LatLng': {'lat': 0, 'lng': 0},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_3981507',
#   'uniqueKey': 'WF_3981507'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:42Z',
#    'Dust2_5': 10,
#    'Humidity': 73,
#    'Temperature': 31.6},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000120',
#    'TOWNENG': 'Beitou District',
#    'TOWNID': 'A16',
#    'TOWNNAME': '北投區'},
#   'LatLng': {'lat': 25.14151, 'lng': 121.48854},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_545016',
#   'uniqueKey': 'WF_545016'},
#  {'Analysis': {'ranking': 1, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:39Z',
#    'Dust2_5': 17,
#    'Humidity': 60.4,
#    'Temperature': 29.6},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000190',
#    'TOWNENG': 'Shanhua District',
#    'TOWNID': 'D27',
#    'TOWNNAME': '善化區'},
#   'LatLng': {'lat': 23.14291, 'lng': 120.27978},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_550866',
#   'uniqueKey': 'WF_550866'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:13Z',
#    'Dust2_5': 12,
#    'Humidity': 55.6,
#    'Temperature': 32.9},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000120',
#    'TOWNENG': 'Beitou District',
#    'TOWNID': 'A16',
#    'TOWNNAME': '北投區'},
#   'LatLng': {'lat': 25.14162, 'lng': 121.48843},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'WF_8322065',
#   'uniqueKey': 'WF_8322065'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:05:01Z',
#    'Dust2_5': 14,
#    'Humidity': 83.7,
#    'Temperature': 32.1},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000310',
#    'TOWNENG': 'Yongkang District',
#    'TOWNID': 'D39',
#    'TOWNNAME': '永康區'},
#   'LatLng': {'lat': 22.99878, 'lng': 120.24559},
#   'Maker': 'LASS',
#   'SiteGroup': 'LASS',
#   'SiteName': 'YK_160',
#   'uniqueKey': 'YK_160'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:58Z',
#    'Dust2_5': 25,
#    'Humidity': 78.54,
#    'Temperature': 29.74},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000030',
#    'TOWNENG': 'Zuoying District',
#    'TOWNID': 'E03',
#    'TOWNNAME': '左營區'},
#   'LatLng': {'lat': 22.67879, 'lng': 120.30313},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_',
#   'uniqueKey': 'FT2_'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:16Z',
#    'Dust2_5': 23,
#    'Humidity': 55.27,
#    'Temperature': 31.31},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000050',
#    'TOWNENG': 'N. District',
#    'TOWNID': 'B05',
#    'TOWNNAME': '北區'},
#   'LatLng': {'lat': 24.158, 'lng': 120.66613},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0002',
#   'uniqueKey': 'FT2_0002'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:03Z',
#    'Dust2_5': 13,
#    'Humidity': 70.69,
#    'Temperature': 30.15},
#   'Geometry': {'COUNTYCODE': '10004',
#    'COUNTYID': 'J',
#    'COUNTYNAME': '新竹縣',
#    'TOWNCODE': '10004070',
#    'TOWNENG': 'Qionglin Township',
#    'TOWNID': 'J10',
#    'TOWNNAME': '芎林鄉'},
#   'LatLng': {'lat': 24.79, 'lng': 121.06448},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0006',
#   'uniqueKey': 'FT2_0006'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:44Z',
#    'Dust2_5': 13,
#    'Humidity': 67.81,
#    'Temperature': 30.28},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000040',
#    'TOWNENG': 'W. District',
#    'TOWNID': 'B04',
#    'TOWNNAME': '西區'},
#   'LatLng': {'lat': 24.14287, 'lng': 120.65872},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0012',
#   'uniqueKey': 'FT2_0012'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:14Z',
#    'Dust2_5': 4,
#    'Humidity': 64.1,
#    'Temperature': 29.52},
#   'Geometry': {'COUNTYCODE': '10018',
#    'COUNTYID': 'O',
#    'COUNTYNAME': '新竹市',
#    'TOWNCODE': '10018010',
#    'TOWNENG': 'E. District',
#    'TOWNID': 'O01',
#    'TOWNNAME': '東區'},
#   'LatLng': {'lat': 24.80159, 'lng': 120.98648},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0021',
#   'uniqueKey': 'FT2_0021'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:39Z',
#    'Dust2_5': 17,
#    'Humidity': 95.29,
#    'Temperature': 24.43},
#   'Geometry': None,
#   'LatLng': {'lat': 1.4342, 'lng': 103.83661},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0024',
#   'uniqueKey': 'FT2_0024'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:26Z',
#    'Dust2_5': 7,
#    'Humidity': 70.65,
#    'Temperature': 28.78},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000170',
#    'TOWNENG': 'Linkou District',
#    'TOWNID': 'F02',
#    'TOWNNAME': '林口區'},
#   'LatLng': {'lat': 25.07823, 'lng': 121.37123},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0028',
#   'uniqueKey': 'FT2_0028'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:22Z',
#    'Dust2_5': 19,
#    'Humidity': 63.35,
#    'Temperature': 30.23},
#   'Geometry': {'COUNTYCODE': '10008',
#    'COUNTYID': 'M',
#    'COUNTYNAME': '南投縣',
#    'TOWNCODE': '10008100',
#    'TOWNENG': 'Guoxing Township',
#    'TOWNID': 'M10',
#    'TOWNNAME': '國姓鄉'},
#   'LatLng': {'lat': 24.09288, 'lng': 120.88799},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0036',
#   'uniqueKey': 'FT2_0036'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:04Z',
#    'Dust2_5': 6,
#    'Humidity': 67.34,
#    'Temperature': 29.85},
#   'Geometry': {'COUNTYCODE': '10018',
#    'COUNTYID': 'O',
#    'COUNTYNAME': '新竹市',
#    'TOWNCODE': '10018010',
#    'TOWNENG': 'E. District',
#    'TOWNID': 'O01',
#    'TOWNNAME': '東區'},
#   'LatLng': {'lat': 24.794, 'lng': 120.9639},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0038',
#   'uniqueKey': 'FT2_0038'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:11Z',
#    'Dust2_5': 2,
#    'Humidity': 40.55,
#    'Temperature': 27.44},
#   'Geometry': {'COUNTYCODE': '68000',
#    'COUNTYID': 'H',
#    'COUNTYNAME': '桃園市',
#    'TOWNCODE': '68000020',
#    'TOWNENG': 'Zhongli District',
#    'TOWNID': 'H03',
#    'TOWNNAME': '中壢區'},
#   'LatLng': {'lat': 24.9704, 'lng': 121.1924},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0041',
#   'uniqueKey': 'FT2_0041'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:02Z',
#    'Dust2_5': 8,
#    'Humidity': 63.58,
#    'Temperature': 27.48},
#   'Geometry': {'COUNTYCODE': '10018',
#    'COUNTYID': 'O',
#    'COUNTYNAME': '新竹市',
#    'TOWNCODE': '10018010',
#    'TOWNENG': 'E. District',
#    'TOWNID': 'O01',
#    'TOWNNAME': '東區'},
#   'LatLng': {'lat': 24.802599999999998, 'lng': 120.9955},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0042',
#   'uniqueKey': 'FT2_0042'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:34Z',
#    'Dust2_5': 8,
#    'Humidity': 76.61,
#    'Temperature': 27.99},
#   'Geometry': {'COUNTYCODE': '10018',
#    'COUNTYID': 'O',
#    'COUNTYNAME': '新竹市',
#    'TOWNCODE': '10018010',
#    'TOWNENG': 'E. District',
#    'TOWNID': 'O01',
#    'TOWNNAME': '東區'},
#   'LatLng': {'lat': 24.77137, 'lng': 120.96339},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0055',
#   'uniqueKey': 'FT2_0055'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:59Z',
#    'Dust2_5': 21,
#    'Humidity': 69.72,
#    'Temperature': 30.86},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000020',
#    'TOWNENG': 'Sanzhong District',
#    'TOWNID': 'F05',
#    'TOWNNAME': '三重區'},
#   'LatLng': {'lat': 25.0673, 'lng': 121.48494},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0056',
#   'uniqueKey': 'FT2_0056'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:53Z',
#    'Dust2_5': 31,
#    'Humidity': 78.64,
#    'Temperature': 30.17},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000090',
#    'TOWNENG': 'Qianzhen District',
#    'TOWNID': 'E09',
#    'TOWNNAME': '前鎮區'},
#   'LatLng': {'lat': 22.61012, 'lng': 120.30294},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0074',
#   'uniqueKey': 'FT2_0074'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:11Z',
#    'Dust2_5': 21,
#    'Humidity': 64.84,
#    'Temperature': 28.79},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000020',
#    'TOWNENG': 'Xinyi District',
#    'TOWNID': 'A17',
#    'TOWNNAME': '信義區'},
#   'LatLng': {'lat': 25.02095, 'lng': 121.573},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0077',
#   'uniqueKey': 'FT2_0077'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:09Z',
#    'Dust2_5': 10,
#    'Humidity': 66.76,
#    'Temperature': 28.17},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000120',
#    'TOWNENG': 'Beitou District',
#    'TOWNID': 'A16',
#    'TOWNNAME': '北投區'},
#   'LatLng': {'lat': 25.11328, 'lng': 121.51281},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0081',
#   'uniqueKey': 'FT2_0081'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:47Z',
#    'Dust2_5': 14,
#    'Humidity': 67.02,
#    'Temperature': 30.13},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000060',
#    'TOWNENG': 'Xitun District',
#    'TOWNID': 'B06',
#    'TOWNNAME': '西屯區'},
#   'LatLng': {'lat': 24.1765, 'lng': 120.6405},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0090',
#   'uniqueKey': 'FT2_0090'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:53Z',
#    'Dust2_5': 29,
#    'Humidity': 61.01,
#    'Temperature': 33.28},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000090',
#    'TOWNENG': 'Nangang District',
#    'TOWNID': 'A13',
#    'TOWNNAME': '南港區'},
#   'LatLng': {'lat': 25.05249, 'lng': 121.61644},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0106',
#   'uniqueKey': 'FT2_0106'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:18Z',
#    'Dust2_5': 16,
#    'Humidity': 61.46,
#    'Temperature': 32.27},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000030',
#    'TOWNENG': 'Zhonghe District',
#    'TOWNID': 'F18',
#    'TOWNNAME': '中和區'},
#   'LatLng': {'lat': 24.99729, 'lng': 121.50884},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0107',
#   'uniqueKey': 'FT2_0107'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:59Z',
#    'Dust2_5': 28,
#    'Humidity': 92.87,
#    'Temperature': 28.11},
#   'Geometry': None,
#   'LatLng': {'lat': 10.7281, 'lng': 106.711},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0110',
#   'uniqueKey': 'FT2_0110'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:29Z',
#    'Dust2_5': 20,
#    'Humidity': 47.74,
#    'Temperature': 36.59},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000080',
#    'TOWNENG': 'Wenshan District',
#    'TOWNID': 'A11',
#    'TOWNNAME': '文山區'},
#   'LatLng': {'lat': 25.00624, 'lng': 121.56055},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0115',
#   'uniqueKey': 'FT2_0115'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:25Z',
#    'Dust2_5': 5,
#    'Humidity': 59.97,
#    'Temperature': 31.72},
#   'Geometry': None,
#   'LatLng': {'lat': -31.00588, 'lng': 24.79694},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0118',
#   'uniqueKey': 'FT2_0118'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:57Z',
#    'Dust2_5': 31,
#    'Humidity': 72.52,
#    'Temperature': 30.31},
#   'Geometry': {'COUNTYCODE': '10010',
#    'COUNTYID': 'Q',
#    'COUNTYNAME': '嘉義縣',
#    'TOWNCODE': '10010050',
#    'TOWNENG': 'Minxueng Township',
#    'TOWNID': 'Q05',
#    'TOWNNAME': '民雄鄉'},
#   'LatLng': {'lat': 23.55667, 'lng': 120.43952},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0120',
#   'uniqueKey': 'FT2_0120'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:20Z',
#    'Dust2_5': 7,
#    'Humidity': 70.08,
#    'Temperature': 29.84},
#   'Geometry': {'COUNTYCODE': '10004',
#    'COUNTYID': 'J',
#    'COUNTYNAME': '新竹縣',
#    'TOWNCODE': '10004010',
#    'TOWNENG': 'Zhubei City',
#    'TOWNID': 'J05',
#    'TOWNNAME': '竹北市'},
#   'LatLng': {'lat': 24.80873, 'lng': 121.03505},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0122',
#   'uniqueKey': 'FT2_0122'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:24Z',
#    'Dust2_5': 3,
#    'Humidity': 74.9,
#    'Temperature': 29.15},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0124',
#   'uniqueKey': 'FT2_0124'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:38Z',
#    'Dust2_5': 14,
#    'Humidity': 68.17,
#    'Temperature': 29.75},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000050',
#    'TOWNENG': 'Xinzhuang District',
#    'TOWNID': 'F01',
#    'TOWNNAME': '新莊區'},
#   'LatLng': {'lat': 25.04694, 'lng': 121.44491},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0125',
#   'uniqueKey': 'FT2_0125'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:23Z',
#    'Dust2_5': 28,
#    'Humidity': 67.57,
#    'Temperature': 30.4},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000080',
#    'TOWNENG': 'Beitun District',
#    'TOWNID': 'B08',
#    'TOWNNAME': '北屯區'},
#   'LatLng': {'lat': 24.19625, 'lng': 120.6855},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0132',
#   'uniqueKey': 'FT2_0132'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:44Z',
#    'Dust2_5': 39,
#    'Humidity': 68.7,
#    'Temperature': 30.1},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0146',
#   'uniqueKey': 'FT2_0146'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:52Z',
#    'Dust2_5': 24,
#    'Humidity': 65.67,
#    'Temperature': 30.53},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0148',
#   'uniqueKey': 'FT2_0148'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:56Z',
#    'Dust2_5': 32,
#    'Humidity': 64.4,
#    'Temperature': 31.37},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0149',
#   'uniqueKey': 'FT2_0149'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:51Z',
#    'Dust2_5': 27,
#    'Humidity': 68.01,
#    'Temperature': 30.27},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0150',
#   'uniqueKey': 'FT2_0150'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:55Z',
#    'Dust2_5': 22,
#    'Humidity': 61.29,
#    'Temperature': 29.92},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0155',
#   'uniqueKey': 'FT2_0155'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:50Z',
#    'Dust2_5': 16,
#    'Humidity': 63.34,
#    'Temperature': 25.43},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0158',
#   'uniqueKey': 'FT2_0158'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:48Z',
#    'Dust2_5': 34,
#    'Humidity': 65.03,
#    'Temperature': 30.63},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0160',
#   'uniqueKey': 'FT2_0160'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:43Z',
#    'Dust2_5': 28,
#    'Humidity': 71.39,
#    'Temperature': 29.62},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0173',
#   'uniqueKey': 'FT2_0173'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:22Z',
#    'Dust2_5': 15,
#    'Humidity': 50.84,
#    'Temperature': 35.2},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000010',
#    'TOWNENG': 'Banqiao District',
#    'TOWNID': 'F14',
#    'TOWNNAME': '板橋區'},
#   'LatLng': {'lat': 25.02588, 'lng': 121.4753},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0176',
#   'uniqueKey': 'FT2_0176'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:25Z',
#    'Dust2_5': 6,
#    'Humidity': 92.85,
#    'Temperature': 28.52},
#   'Geometry': {'COUNTYCODE': '10015',
#    'COUNTYID': 'U',
#    'COUNTYNAME': '花蓮縣',
#    'TOWNCODE': '10015010',
#    'TOWNENG': 'Hualien City',
#    'TOWNID': 'U01',
#    'TOWNNAME': '花蓮市'},
#   'LatLng': {'lat': 23.97695, 'lng': 121.62668},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0177',
#   'uniqueKey': 'FT2_0177'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:56Z',
#    'Dust2_5': 30,
#    'Humidity': 70.48,
#    'Temperature': 29.58},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000050',
#    'TOWNENG': 'Zhongzheng District',
#    'TOWNID': 'A03',
#    'TOWNNAME': '中正區'},
#   'LatLng': {'lat': 25.04327, 'lng': 121.52278},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0178',
#   'uniqueKey': 'FT2_0178'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:24Z',
#    'Dust2_5': 25,
#    'Humidity': 77.33,
#    'Temperature': 28.12},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000060',
#    'TOWNENG': 'Xindian District',
#    'TOWNID': 'F07',
#    'TOWNNAME': '新店區'},
#   'LatLng': {'lat': 24.96276, 'lng': 121.51289},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0185',
#   'uniqueKey': 'FT2_0185'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:29Z',
#    'Dust2_5': 7,
#    'Humidity': 66.25,
#    'Temperature': 29.42},
#   'Geometry': None,
#   'LatLng': {'lat': -31.03059, 'lng': 24.80555},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0195',
#   'uniqueKey': 'FT2_0195'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:07Z',
#    'Dust2_5': 22,
#    'Humidity': 59.3,
#    'Temperature': 31.94},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000030',
#    'TOWNENG': 'Daan District',
#    'TOWNID': 'A02',
#    'TOWNNAME': '大安區'},
#   'LatLng': {'lat': 25.02406, 'lng': 121.53862},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0198',
#   'uniqueKey': 'FT2_0198'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:35Z',
#    'Dust2_5': 0,
#    'Humidity': 0,
#    'Temperature': 0},
#   'Geometry': None,
#   'LatLng': {'lat': 41.89068, 'lng': -87.62426},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0205',
#   'uniqueKey': 'FT2_0205'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:49Z',
#    'Dust2_5': 21,
#    'Humidity': 63.97,
#    'Temperature': 31.65},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000010',
#    'TOWNENG': 'Banqiao District',
#    'TOWNID': 'F14',
#    'TOWNNAME': '板橋區'},
#   'LatLng': {'lat': 24.99564, 'lng': 121.43122},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0209',
#   'uniqueKey': 'FT2_0209'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:38Z',
#    'Dust2_5': 17,
#    'Humidity': 57.61,
#    'Temperature': 22.88},
#   'Geometry': None,
#   'LatLng': {'lat': 25.74538, 'lng': 123.4751},
#   'Maker': 'LASS-4U',
#   'SiteGroup': 'LASS-4U',
#   'SiteName': 'FT2_0222',
#   'uniqueKey': 'FT2_0222'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:26Z',
#    'Dust2_5': 42,
#    'Humidity': 64.47,
#    'Temperature': 26.2},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
# ...
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000070',
#    'TOWNENG': 'Nantun District',
#    'TOWNID': 'B07',
#    'TOWNNAME': '南屯區'},
#   'LatLng': {'lat': 24.151, 'lng': 120.644},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '2F 戶外',
#   'uniqueKey': '74DA38B05198'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:49Z',
#    'Dust2_5': 15,
#    'Humidity': 87,
#    'Temperature': 31.86},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000360',
#    'TOWNENG': 'Anping District',
#    'TOWNID': 'D07',
#    'TOWNNAME': '安平區'},
#   'LatLng': {'lat': 22.999, 'lng': 120.159},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '安平古堡_4G',
#   'uniqueKey': '74DA38B0519C'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:04Z',
#    'Dust2_5': 17,
#    'Humidity': 100,
#    'Temperature': 33.25},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000360',
#    'TOWNENG': 'Anping District',
#    'TOWNID': 'D07',
#    'TOWNNAME': '安平區'},
#   'LatLng': {'lat': 22.989, 'lng': 120.184},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '市政中心(永華路)_4G',
#   'uniqueKey': '74DA38B0519E'},
#  {'Analysis': {'ranking': 2, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:16Z',
#    'Dust2_5': 27,
#    'Humidity': 74,
#    'Temperature': 31.11},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000110',
#    'TOWNENG': 'Xizhi District',
#    'TOWNID': 'F28',
#    'TOWNNAME': '汐止區'},
#   'LatLng': {'lat': 25.066, 'lng': 121.636},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'EC house',
#   'uniqueKey': '74DA38B051A2'},
#  {'Analysis': {'ranking': 1, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:02:46Z',
#    'Dust2_5': 39,
#    'Humidity': 72,
#    'Temperature': 30},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000050',
#    'TOWNENG': 'Xinzhuang District',
#    'TOWNID': 'F01',
#    'TOWNNAME': '新莊區'},
#   'LatLng': {'lat': 25.062, 'lng': 121.451},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '虎尾家裡',
#   'uniqueKey': '74DA38B051A6'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:02:08Z',
#    'Dust2_5': 1,
#    'Humidity': 71,
#    'Temperature': 29.25},
#   'Geometry': {'COUNTYCODE': '10018',
#    'COUNTYID': 'O',
#    'COUNTYNAME': '新竹市',
#    'TOWNCODE': '10018010',
#    'TOWNENG': 'E. District',
#    'TOWNID': 'O01',
#    'TOWNNAME': '東區'},
#   'LatLng': {'lat': 24.8, 'lng': 120.993},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'EdiGreen_wllai',
#   'uniqueKey': '74DA38B051A8'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:06:40Z',
#    'Dust2_5': 6,
#    'Humidity': 100,
#    'Temperature': 31.75},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002050',
#    'TOWNENG': 'Jiaoxi Township',
#    'TOWNID': 'G03',
#    'TOWNNAME': '礁溪鄉'},
#   'LatLng': {'lat': 24.8, 'lng': 121.783},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '青天計畫2.0 - 礁溪玉田村踏踏路',
#   'uniqueKey': '74DA38B051B0'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:02Z',
#    'Dust2_5': 15,
#    'Humidity': 78,
#    'Temperature': 30.75},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002070',
#    'TOWNENG': 'Yuanshan Township',
#    'TOWNID': 'G05',
#    'TOWNNAME': '員山鄉'},
#   'LatLng': {'lat': 24.724, 'lng': 121.732},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '青天計劃2.0 - 員山惠深二路',
#   'uniqueKey': '74DA38B051B2'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:55Z',
#    'Dust2_5': 7,
#    'Humidity': 100,
#    'Temperature': 32},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002050',
#    'TOWNENG': 'Jiaoxi Township',
#    'TOWNID': 'G03',
#    'TOWNNAME': '礁溪鄉'},
#   'LatLng': {'lat': 24.803, 'lng': 121.807},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '青天計畫2.0 - 礁溪時潮村塭底路',
#   'uniqueKey': '74DA38B051B4'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:35Z',
#    'Dust2_5': 25,
#    'Humidity': 57,
#    'Temperature': 33.86},
#   'Geometry': {'COUNTYCODE': '10013',
#    'COUNTYID': 'T',
#    'COUNTYNAME': '屏東縣',
#    'TOWNCODE': '10013130',
#    'TOWNENG': 'Neipu Township',
#    'TOWNID': 'T13',
#    'TOWNNAME': '內埔鄉'},
#   'LatLng': {'lat': 22.607, 'lng': 120.563},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '永平街',
#   'uniqueKey': '74DA38B051B8'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:46Z',
#    'Dust2_5': 8,
#    'Humidity': 76,
#    'Temperature': 31.5},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002060',
#    'TOWNENG': 'Zhuangwei Township',
#    'TOWNID': 'G04',
#    'TOWNNAME': '壯圍鄉'},
#   'LatLng': {'lat': 24.78, 'lng': 121.791},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '青天計畫2.0 - 壯圍十八島',
#   'uniqueKey': '74DA38B051BC'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:20Z',
#    'Dust2_5': 3,
#    'Humidity': 98,
#    'Temperature': 30.36},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002040',
#    'TOWNENG': 'Toucheng Township',
#    'TOWNID': 'G02',
#    'TOWNNAME': '頭城鎮'},
#   'LatLng': {'lat': 24.905, 'lng': 121.848},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '青天計畫2.0 - 頭城休閒農場',
#   'uniqueKey': '74DA38B051BE'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:38Z',
#    'Dust2_5': 7,
#    'Humidity': 80,
#    'Temperature': 28.86},
#   'Geometry': {'COUNTYCODE': '10002',
#    'COUNTYID': 'G',
#    'COUNTYNAME': '宜蘭縣',
#    'TOWNCODE': '10002090',
#    'TOWNENG': 'Wujie Township',
#    'TOWNID': 'G07',
#    'TOWNNAME': '五結鄉'},
#   'LatLng': {'lat': 24.707, 'lng': 121.816},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '宜蘭縣-五結鄉錦草劉德華家',
#   'uniqueKey': '74DA38B051C0'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:32Z',
#    'Dust2_5': 21,
#    'Humidity': 60,
#    'Temperature': 31.75},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000070',
#    'TOWNENG': 'Wanhua District',
#    'TOWNID': 'A05',
#    'TOWNNAME': '萬華區'},
#   'LatLng': {'lat': 25.028, 'lng': 121.494},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '小威哥的家',
#   'uniqueKey': '74DA38B051CA'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:48Z',
#    'Dust2_5': 26,
#    'Humidity': 72,
#    'Temperature': 29.25},
#   'Geometry': {'COUNTYCODE': '10008',
#    'COUNTYID': 'M',
#    'COUNTYNAME': '南投縣',
#    'TOWNCODE': '10008110',
#    'TOWNENG': 'Shuili Township',
#    'TOWNID': 'M11',
#    'TOWNNAME': '水里鄉'},
#   'LatLng': {'lat': 23.731, 'lng': 120.852},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '奕青莊園',
#   'uniqueKey': '74DA38B051CC'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:09Z',
#    'Dust2_5': 16,
#    'Humidity': 100,
#    'Temperature': 34.61},
#   'Geometry': {'COUNTYCODE': '67000',
#    'COUNTYID': 'D',
#    'COUNTYNAME': '臺南市',
#    'TOWNCODE': '67000350',
#    'TOWNENG': 'Annan District',
#    'TOWNID': 'D06',
#    'TOWNNAME': '安南區'},
#   'LatLng': {'lat': 23.048, 'lng': 120.217},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'NTU安順國小站-1',
#   'uniqueKey': '74DA38B051DE'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:44Z',
#    'Dust2_5': 9,
#    'Humidity': 100,
#    'Temperature': 30.5},
#   'Geometry': {'COUNTYCODE': '10009',
#    'COUNTYID': 'P',
#    'COUNTYNAME': '雲林縣',
#    'TOWNCODE': '10009130',
#    'TOWNENG': 'Mailiao Township',
#    'TOWNID': 'P13',
#    'TOWNNAME': '麥寮鄉'},
#   'LatLng': {'lat': 23.796, 'lng': 120.223},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '許厝分校',
#   'uniqueKey': '74DA38B051F0'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:14Z',
#    'Dust2_5': 12,
#    'Humidity': 69,
#    'Temperature': 31.36},
#   'Geometry': {'COUNTYCODE': '10009',
#    'COUNTYID': 'P',
#    'COUNTYNAME': '雲林縣',
#    'TOWNCODE': '10009130',
#    'TOWNENG': 'Mailiao Township',
#    'TOWNID': 'P13',
#    'TOWNNAME': '麥寮鄉'},
#   'LatLng': {'lat': 23.797, 'lng': 120.273},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '雲林縣橋頭國小',
#   'uniqueKey': '74DA38B051F2'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:05:15Z',
#    'Dust2_5': 7,
#    'Humidity': 59,
#    'Temperature': 31.61},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000030',
#    'TOWNENG': 'Daan District',
#    'TOWNID': 'A02',
#    'TOWNNAME': '大安區'},
#   'LatLng': {'lat': 25.034, 'lng': 121.525},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'James',
#   'uniqueKey': '74DA38B051F4'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:01:43Z',
#    'Dust2_5': 31,
#    'Humidity': 77,
#    'Temperature': 29.75},
#   'Geometry': {'COUNTYCODE': '10010',
#    'COUNTYID': 'Q',
#    'COUNTYNAME': '嘉義縣',
#    'TOWNCODE': '10010040',
#    'TOWNENG': 'Dalin Township',
#    'TOWNID': 'Q04',
#    'TOWNNAME': '大林鎮'},
#   'LatLng': {'lat': 23.594, 'lng': 120.457},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '大林慈濟宿舍',
#   'uniqueKey': '74DA38B051FA'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:07:04Z',
#    'Dust2_5': 12,
#    'Humidity': 70,
#    'Temperature': 32.61},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000120',
#    'TOWNENG': 'Beitou District',
#    'TOWNID': 'A16',
#    'TOWNNAME': '北投區'},
#   'LatLng': {'lat': 25.105, 'lng': 121.515},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'NTU文林國小-2',
#   'uniqueKey': '74DA38B051FE'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:02:40Z',
#    'Dust2_5': 27,
#    'Humidity': 59,
#    'Temperature': 32},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000040',
#    'TOWNENG': 'Zhongshan District',
#    'TOWNID': 'A10',
#    'TOWNNAME': '中山區'},
#   'LatLng': {'lat': 25.077, 'lng': 121.548},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '乾淨空氣',
#   'uniqueKey': '74DA38B05202'},
#  {'Analysis': {'ranking': None, 'status': 'longterm-pollution|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:02:02Z',
#    'Dust2_5': 22,
#    'Humidity': 63,
#    'Temperature': 25.25},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000010',
#    'TOWNENG': 'Songshan District',
#    'TOWNID': 'A01',
#    'TOWNNAME': '松山區'},
#   'LatLng': {'lat': 25.058, 'lng': 121.562},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'TK Green',
#   'uniqueKey': '74DA38B05204'},
#  {'Analysis': {'ranking': 0, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:04:18Z',
#    'Dust2_5': 32,
#    'Humidity': 66,
#    'Temperature': 31.25},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000040',
#    'TOWNENG': 'Zhongshan District',
#    'TOWNID': 'A10',
#    'TOWNNAME': '中山區'},
#   'LatLng': {'lat': 25.062, 'lng': 121.528},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '家家',
#   'uniqueKey': '74DA38B05208'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:05:05Z',
#    'Dust2_5': 23,
#    'Humidity': 63,
#    'Temperature': 30.36},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000030',
#    'TOWNENG': 'Zhonghe District',
#    'TOWNID': 'F18',
#    'TOWNNAME': '中和區'},
#   'LatLng': {'lat': 24.998, 'lng': 121.511},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'Joan Ching',
#   'uniqueKey': '74DA38B0520C'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:06:03Z',
#    'Dust2_5': 10,
#    'Humidity': 64,
#    'Temperature': 31.61},
#   'Geometry': {'COUNTYCODE': '65000',
#    'COUNTYID': 'F',
#    'COUNTYNAME': '新北市',
#    'TOWNCODE': '65000060',
#    'TOWNENG': 'Xindian District',
#    'TOWNID': 'F07',
#    'TOWNNAME': '新店區'},
#   'LatLng': {'lat': 24.958, 'lng': 121.497},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '新店垃圾焚化廠行政大樓門口',
#   'uniqueKey': '74DA38B0520E'},
#  {'Analysis': {'ranking': 3, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:07:30Z',
#    'Dust2_5': 24,
#    'Humidity': 98,
#    'Temperature': 35.61},
#   'Geometry': {'COUNTYCODE': '66000',
#    'COUNTYID': 'B',
#    'COUNTYNAME': '臺中市',
#    'TOWNCODE': '66000160',
#    'TOWNENG': 'Shengang District',
#    'TOWNID': 'B16',
#    'TOWNNAME': '神岡區'},
#   'LatLng': {'lat': 24.252, 'lng': 120.698},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '大裡街',
#   'uniqueKey': '74DA38B05212'},
#  {'Analysis': {'ranking': 1, 'status': 'indoor|malfunction'},
#   'Data': {'Create_at': '2018-06-27T04:03:25Z',
#    'Dust2_5': 16,
#    'Humidity': 55,
#    'Temperature': 30.86},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000030',
#    'TOWNENG': 'Zuoying District',
#    'TOWNID': 'E03',
#    'TOWNNAME': '左營區'},
#   'LatLng': {'lat': 22.683, 'lng': 120.318},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '菜公一路',
#   'uniqueKey': '74DA38B05214'},
#  {'Analysis': {'ranking': None, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:06:32Z',
#    'Dust2_5': 18,
#    'Humidity': 66,
#    'Temperature': 29.75},
#   'Geometry': {'COUNTYCODE': '63000',
#    'COUNTYID': 'A',
#    'COUNTYNAME': '臺北市',
#    'TOWNCODE': '63000050',
#    'TOWNENG': 'Zhongzheng District',
#    'TOWNID': 'A03',
#    'TOWNNAME': '中正區'},
#   'LatLng': {'lat': 25.042, 'lng': 121.517},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '台大醫院5',
#   'uniqueKey': '74DA38B05216'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:18Z',
#    'Dust2_5': 29,
#    'Humidity': 100,
#    'Temperature': 30.5},
#   'Geometry': {'COUNTYCODE': '64000',
#    'COUNTYID': 'E',
#    'COUNTYNAME': '高雄市',
#    'TOWNCODE': '64000110',
#    'TOWNENG': 'Xiaogang District',
#    'TOWNID': 'E11',
#    'TOWNNAME': '小港區'},
#   'LatLng': {'lat': 22.565, 'lng': 120.337},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'NTU 小港國中站-1',
#   'uniqueKey': '74DA38B05218'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:06:46Z',
#    'Dust2_5': 27,
#    'Humidity': 69,
#    'Temperature': 28.86},
#   'Geometry': None,
#   'LatLng': {'lat': -6.188, 'lng': 106.87},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'Edigreen DP',
#   'uniqueKey': '74DA38B05224'},
#  {'Analysis': {'ranking': 4, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:03:06Z',
#    'Dust2_5': 6,
#    'Humidity': 58,
#    'Temperature': 35.75},
#   'Geometry': {'COUNTYCODE': '10005',
#    'COUNTYID': 'K',
#    'COUNTYNAME': '苗栗縣',
#    'TOWNCODE': '10005040',
#    'TOWNENG': 'Zhunan Township',
#    'TOWNID': 'K09',
#    'TOWNNAME': '竹南鎮'},
#   'LatLng': {'lat': 24.683, 'lng': 120.881},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': 'Donping',
#   'uniqueKey': '74DA38B0522A'},
#  {'Analysis': {'ranking': 5, 'status': None},
#   'Data': {'Create_at': '2018-06-27T04:04:52Z',
#    'Dust2_5': 28,
#    'Humidity': 77,
#    'Temperature': 30.25},
#   'Geometry': {'COUNTYCODE': '10020',
#    'COUNTYID': 'I',
#    'COUNTYNAME': '嘉義市',
#    'TOWNCODE': '10020020',
#    'TOWNENG': 'W. District',
#    'TOWNID': 'I02',
#    'TOWNNAME': '西區'},
#   'LatLng': {'lat': 23.464, 'lng': 120.439},
#   'Maker': 'Edimax',
#   'SiteGroup': 'Edimax',
#   'SiteName': '嘉義市民生國中',
#   'uniqueKey': '74DA38B0522C'},
#  ...]

# %%
# Out:
# <Response [403]>

# %%
# Out:
# https://maps.googleapis.com/maps/api/distancematrix/json?origins=24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.69624.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.69624.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.69624.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.69624.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696|24.12891,120.69053|24.137,120.699|24.14552,120.69336|24.1315,120.68464|24.138,120.694|24.124,120.696&destinations=24.158999,120.685569&mode=driving&language=zh-TW&key=AIzaSyD9ojwRyJKMDqorLnjpoaRT7s94S2EAkVA

# %%
map_des
# Out:
# '24.158999,120.685569'

# %%
map_ori_list
# Out:
# ['東區',
#  '北區',
#  '神岡區',
#  '清水區',
#  '龍井區',
#  '新社區',
#  '北屯區',
#  '西屯區',
#  '大安區',
#  '潭子區',
#  '烏日區',
#  '霧峰區',
#  '南區',
#  '沙鹿區',
#  '西區',
#  '大里區',
#  '后里區',
#  '大雅區',
#  '梧棲區',
#  '東勢區',
#  '和平區',
#  '大肚區',
#  '太平區',
#  '石岡區',
#  '大甲區',
#  '豐原區',
#  '南屯區',
#  '外埔區']

# %%
get_map.index(min(get_map))
